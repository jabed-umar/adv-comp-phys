# %%
import numpy as np
import matplotlib.pyplot as plt
from Library.Lin_alg import*

# %% [markdown]
# # Q.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <h2> Power Method

# %%
# Example usage
A = np.array([[4,2/3,-4/3,4/3],
     [2/3,4,0,0],
     [-4/3,0,6,2],
     [4/3,0,2,6]])  # Sample square matrix
eigenvalue, eigenvector = power_iteration(A)

print("Dominant eigenvalue:", eigenvalue)
print()
print("Corresponding eigenvector:", eigenvector)
# Out:
# Dominant eigenvalue: 8.000000000000002
#
# Corresponding eigenvector: [1.95491977e-10 6.51639893e-11 7.07106781e-01 7.07106781e-01]

# %% [markdown]
# # <h2> QR Factorisation
